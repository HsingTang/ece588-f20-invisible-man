# %%
import os
from deepface import DeepFace
from matplotlib import pyplot as plt

# %%
cwd = os.getcwd()
path = cwd+'/../data/IM_0'

# %%
fig, axes = plt.subplots(5, 2)
for i in range(10):
    try:
        print(f'Running on IM_0{str(i)}...')
        img_path = path + str(i) +'.jpg'
        detected_face = DeepFace.detectFace(img_path)
        axes[(int)(i/2)][i%2].imshow(detected_face)
    except ValueError as e:
        print('Face detection failed: '+str(e))
# Out:
# Running on IM_00...
# Running on IM_01...
# Running on IM_02...
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Running on IM_03...
# Running on IM_04...
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Running on IM_05...
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Running on IM_06...
# Running on IM_07...
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Running on IM_08...
# Running on IM_09...
