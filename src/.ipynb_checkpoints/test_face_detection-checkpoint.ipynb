# %%
import cv2
import os
import numpy as np
from deepface import DeepFace
from deepface.commons import functions
from matplotlib import pyplot as plt

# %%
cwd = os.getcwd()
path = cwd+'/../data/IM_'

# %%
plt.rcParams['figure.figsize'] = [60, 30]
num_images = 4

# %%
backends = ['opencv', 'ssd', 'dlib', 'mtcnn']
all_faces = []
for backend in backends:
    print(f'backend: {backend}')
    faces = []
    for i in range(num_images):
        try:
            image_idx = str(i).zfill(2)
            # print(f'Running on IM_{image_idx}...')
            img_path = path + image_idx +'.jpg'
            detected_face = DeepFace.detectFace(img_path, detector_backend = backend)
            faces.append(detected_face)
        except ValueError as e:
            print('Face detection failed: '+str(e))
    all_faces.append(faces)
# Out:
# backend: opencv
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# ...

# %%
fig, axes = plt.subplots(max(len(x) for x in all_faces),len(all_faces))
for i in range(len(backends)):
    axes[0,i].set_title(backends[i])
    for j in range(len(all_faces[i])):
        axes[j,i].imshow(all_faces[i][j])

# %%
for i in range(num_images):
    image_idx = str(i).zfill(2)
    print(f'Denoising IM_{image_idx}...')
    img_path = path + image_idx +'.jpg'
    img = cv2.imread(img_path)
    b,g,r = cv2.split(img)
    nlm_img = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
    b,g,r = cv2.split(nlm_img)
    rgb_nlm_img = cv2.merge([r,g,b])
    nlm_path = path + str(i) +'_nlm.jpg'
    cv2.imwrite(nlm_path,nlm_img)
# Out:
# Denoising IM_00...
# Denoising IM_01...
# Denoising IM_02...
# Denoising IM_03...
# Denoising IM_04...
# Denoising IM_05...
# Denoising IM_06...
# Denoising IM_07...
# Denoising IM_08...
# Denoising IM_09...
# Denoising IM_10...
# Denoising IM_11...
# Denoising IM_12...
# Denoising IM_13...
# Denoising IM_14...

# %%
backends = ['opencv', 'ssd', 'dlib', 'mtcnn']
all_faces_denoised = []
for backend in backends:
    print(f'backend: {backend}')
    faces = []
    for i in range(num_images):
        try:
            image_idx = str(i).zfill(2)
            img_path = path + image_idx +'_nlm.jpg'
            detected_face = DeepFace.detectFace(img_path, detector_backend = backend)
            faces.append(detected_face)
        except ValueError as e:
            print('Face detection failed: '+str(e))
    all_faces_denoised.append(faces)
# Out:
# backend: opencv
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Face detection failed: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# ...

# %%
fig, axes = plt.subplots(max(len(x) for x in all_faces_denoised),len(all_faces_denoised))
for i in range(len(backends)):
    axes[0,i].set_title(backends[i])
    for j in range(len(all_faces_denoised[i])):
        axes[j,i].imshow(all_faces_denoised[i][j])

# %%
# dlib does the best job in finding faces, surprisingly without denoising works better.

# %%
print(all_faces[0][0].shape)
# Out:
# (224, 224, 3)

# %%
def locate_face(face, image):
    x,y,w,h = 0,0,face.shape[1],face.shape[0]
    dist_min = -1
    face_b, face_g, face_r = cv2.split(face)
    # Iterate through all windows to find the one closest to the extracted face
    for i in range(image.shape[0]-h): # row
        for j in range(image.shape[1]-w): # column
            window = image[i:i+h, j:j+w]
            window_b,window_g,window_r = cv2.split(window)
            dist = np.linalg.norm(window_b-face_b)+np.linalg.norm(window_g-face_g)+np.linalg.norm(window_r-face_r)
            if(dist_min<0 or dist<dist_min):
                x = j
                y = i
                dist_min = dist
                # print(f'found new dist = {dist} at {x},{y}')
    return x,y,w,h,dist_min

# %%
img = cv2.imread(path + '00.jpg')
face_rgb = all_faces[2][0]
face_bgr = face_rgb[:,:,::-1] # rgb to bgr
x,y,w,h,dist = locate_face(face_bgr, img)
print(f'Found face at x = {x}, y = {y}, dist = {dist}')
# Out:
# Found face at x = 3, y = 1049, dist = 13786.693359375

# %%
face_raw = functions.detect_face(img, 'dlib')
plt.imshow(face_raw[:,:,::-1])
print(face_raw.shape)
# Out:
# (52, 52, 3)

# %%
face_resized = cv2.resize(face_raw, (224,224))
plt.imshow(face_resized[:,:,::-1])

# %%
x,y,w,h,dist = locate_face(face_raw, img)
print(f'Found face at x = {x}, y = {y}, dist = {dist}')
window = img[y:y+h, x:x+w, ::-1]
plt.imshow(window)
# Out:
# Found face at x = 515, y = 216, dist = 0.0

# %%
def detect_face_coord(image_path):
    img = cv2.imread(path)
    x,y,w,h = 0
    try:
        face_raw = functions.detect_face(img, 'dlib')
        x,y,w,h,dist = locate_face(face_raw, img)
    except ValueError as e:
        print(f'Face detection failed on image {image_path}')
    return x,y,w,h
